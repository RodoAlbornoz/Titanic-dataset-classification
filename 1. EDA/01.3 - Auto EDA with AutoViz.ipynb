# %% [markdown]
# Let's complement our manual EDA analysis using the Auto EDA library AutoViz

# %% [markdown]
# Import required libraries

# %%
import matplotlib
import pandas as pd

from autoviz.AutoViz_Class import AutoViz_Class

import sys
import os

# %% [markdown]
# Import train dataset path

# %%
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "..")))

from Datasets.Datasets_paths import ds_train_path

# %% [markdown]
# Print library versions

# %%
print(f'Matplotlib version: {matplotlib.__version__}')
print(f'Pandas Version: {pd.__version__}')
# Out:
# Matplotlib version: 3.6.3
# Pandas Version: 1.5.3

# %% [markdown]
# Add for better visualization

# %%
# %matplotlib inline

# %% [markdown]
# Load train dataset

# %%
ds_titanic_train = pd.read_csv(ds_train_path, encoding = 'unicode_escape')
ds_work = ds_titanic_train.copy()

# %% [markdown]
# # Checking correct load of dataset

# %% [markdown]
# Show first 10 registers

# %%
ds_work.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0       1           0        3
# 1       2           1        1
# 2       3           1        3
# 3       4           1        1
# 4       5           0        3
# 5       6           0        3
# 6       7           0        1
# 7       8           0        3
# 8       9           1        3
# 9      10           1        2
#
#                           Name                           Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0    1
# 2                               Heikkinen, Miss. Laina  female  26.0    0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1
# 4                             Allen, Mr. William Henry    male  35.0    0
# 5                                     Moran, Mr. James    male   NaN    0
# 6                              McCarthy, Mr. Timothy J    male  54.0    0
# ...

# %% [markdown]
# Show last 10 registers

# %%
ds_work.tail(10)
# Out:
#      PassengerId  Survived  Pclass                    Name                    \
# 881      882          0        3                          Markun, Mr. Johann
# 882      883          0        3                Dahlberg, Miss. Gerda Ulrika
# 883      884          0        2               Banfield, Mr. Frederick James
# 884      885          0        3                      Sutehall, Mr. Henry Jr
# 885      886          0        3        Rice, Mrs. William (Margaret Norton)
# 886      887          0        2                       Montvila, Rev. Juozas
# 887      888          1        1                Graham, Miss. Margaret Edith
# 888      889          0        3    Johnston, Miss. Catherine Helen "Carrie"
# 889      890          1        1                       Behr, Mr. Karl Howell
# 890      891          0        3                         Dooley, Mr. Patrick
#
#       Sex     Age  SibSp  Parch       Ticket        Fare   Cabin Embarked
# ...

# %% [markdown]
# Show 10 random registers

# %%
ds_work.sample(10)
# Out:
#      PassengerId  Survived  Pclass              Name                Sex    \
# 725      726          0        3              Oreskovic, Mr. Luka    male
# 411      412          0        3                  Hart, Mr. Henry    male
# 412      413          1        1           Minahan, Miss. Daisy E  female
# 32        33          1        3         Glynn, Miss. Mary Agatha  female
# 660      661          1        1    Frauenthal, Dr. Henry William    male
# 816      817          0        3     Heininen, Miss. Wendla Maria  female
# 438      439          0        1                Fortune, Mr. Mark    male
# 844      845          0        3              Culumovic, Mr. Jeso    male
# 748      749          0        1        Marvin, Mr. Daniel Warner    male
# 329      330          1        1     Hippach, Miss. Jean Gertrude  female
#
#       Age  SibSp  Parch       Ticket         Fare      Cabin     Embarked
# 725  20.0    0      0              315094    8.6625          NaN     S
# ...

# %% [markdown]
# Shape of dataset

# %%
ds_work.shape
# Out:
# (891, 12)

# %% [markdown]
# # Using AutoViz

# %%
AV = AutoViz_Class()

# %%
ds_work = AV.AutoViz(ds_train_path)
# Out:
# Shape of your Data Set loaded: (891, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     12 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['PassengerId']
# To fix data quality issues automatically, import FixDQ from autoviz...
# <style type="text/css">
# ...

# %% [markdown]
# From this, we can conclude that some features seem to be imbalanced (There are a lot more rows of one type than the others): Survived, Pclass, Sex, SibSp, Parch and Embarked. This also supports some of our conjectures from our EDA notebook.
