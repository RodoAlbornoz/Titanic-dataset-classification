# %% [markdown]
# # Let's complement our manual EDA analysis using the Auto EDA library AutoViz

# %% [markdown]
# Import required libraries

# %%
import matplotlib
import pandas as pd

from autoviz.AutoViz_Class import AutoViz_Class

# %% [markdown]
# Print library versions to avoid conflicts

# %%
print(f'Matplotlib version: {matplotlib.__version__}')
print(f'Pandas Version: {pd.__version__}')
# Out:
# Matplotlib version: 3.6.3
# Pandas Version: 1.5.3

# %% [markdown]
# Add some configurations

# %%
# %matplotlib inline

# %% [markdown]
# Load the train dataset

# %%
ds_titanic_train = pd.read_csv(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\train.csv", encoding = 'unicode_escape')
ds_work = ds_titanic_train.copy()

# %% [markdown]
# # Using AutoViz

# %%
AV = AutoViz_Class()

# %%
ds_work = AV.AutoViz(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\train.csv")
# Out:
# Shape of your Data Set loaded: (891, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     12 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['PassengerId']
# To fix data quality issues automatically, import FixDQ from autoviz...
# <style type="text/css">
# #T_08745_row0_col0, #T_08745_row0_col2, #T_08745_row0_col5, #T_08745_row1_col0, #T_08745_row1_col2, #T_08745_row1_col5, #T_08745_row2_col0, #T_08745_row2_col2, #T_08745_row2_col5, #T_08745_row3_col0, #T_08745_row3_col2, #T_08745_row3_col5, #T_08745_row4_col0, #T_08745_row4_col2, #T_08745_row4_col5, #T_08745_row5_col0, #T_08745_row5_col2, #T_08745_row5_col5, #T_08745_row6_col0, #T_08745_row6_col2, #T_08745_row6_col5, #T_08745_row7_col0, #T_08745_row7_col2, #T_08745_row7_col5, #T_08745_row8_col0, #T_08745_row8_col2, #T_08745_row8_col5, #T_08745_row9_col0, #T_08745_row9_col2, #T_08745_row9_col5, #T_08745_row10_col0, #T_08745_row10_col2, #T_08745_row10_col5, #T_08745_row11_col0, #T_08745_row11_col2, #T_08745_row11_col5 {
#   font-family: Segoe UI;
# }
# #T_08745_row0_col1, #T_08745_row1_col1, #T_08745_row1_col3, #T_08745_row1_col4, #T_08745_row2_col1, #T_08745_row2_col4, #T_08745_row3_col1, #T_08745_row4_col1, #T_08745_row6_col1, #T_08745_row6_col3, #T_08745_row7_col1, #T_08745_row7_col3, #T_08745_row8_col1, #T_08745_row9_col1, #T_08745_row9_col3, #T_08745_row11_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_08745_row0_col3, #T_08745_row0_col4, #T_08745_row2_col3, #T_08745_row10_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_08745_row3_col3, #T_08745_row3_col4, #T_08745_row4_col3, #T_08745_row4_col4, #T_08745_row8_col3, #T_08745_row8_col4, #T_08745_row10_col3, #T_08745_row10_col4, #T_08745_row11_col3, #T_08745_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_08745_row5_col1 {
#   background-color: #fcb99f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_08745_row5_col3 {
#   background-color: #fc8464;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_08745_row5_col4 {
#   background-color: #fee7db;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_08745_row6_col4 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_08745_row7_col4 {
#   background-color: #fff4ef;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_08745_row9_col4 {
#   background-color: #f44d38;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_08745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08745_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_08745_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_08745_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_08745_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_08745_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_08745_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08745_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_08745_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_08745_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_08745_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_08745_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_08745_row0_col4" class="data row0 col4" >891.000000</td>
#       <td id="T_08745_row0_col5" class="data row0 col5" >Possible ID colum: drop before modeling process.</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_08745_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_08745_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_08745_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_08745_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_08745_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_08745_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_08745_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_08745_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_08745_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_08745_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_08745_row2_col4" class="data row2 col4" >3.000000</td>
#       <td id="T_08745_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row3" class="row_heading level0 row3" >Name</th>
#       <td id="T_08745_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_08745_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_08745_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_08745_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_08745_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_08745_row3_col5" class="data row3 col5" >Possible ID colum: drop before modeling process., 891 rare categories: Too many to list. Group them into a single category or drop the categories., high cardinality with 891 unique values: Use hash encoding or embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row4" class="row_heading level0 row4" >Sex</th>
#       <td id="T_08745_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_08745_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_08745_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_08745_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_08745_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_08745_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row5" class="row_heading level0 row5" >Age</th>
#       <td id="T_08745_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_08745_row5_col1" class="data row5 col1" >19.865320</td>
#       <td id="T_08745_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_08745_row5_col3" class="data row5 col3" >0.420000</td>
#       <td id="T_08745_row5_col4" class="data row5 col4" >80.000000</td>
#       <td id="T_08745_row5_col5" class="data row5 col5" >177 missing values. Impute them with mean, median, mode, or a constant value such as 123., has 11 outliers greater than upper bound (64.81) or lower than lower bound(-6.69). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row6" class="row_heading level0 row6" >SibSp</th>
#       <td id="T_08745_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_08745_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_08745_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_08745_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_08745_row6_col4" class="data row6 col4" >8.000000</td>
#       <td id="T_08745_row6_col5" class="data row6 col5" >has 46 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row7" class="row_heading level0 row7" >Parch</th>
#       <td id="T_08745_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_08745_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_08745_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_08745_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_08745_row7_col4" class="data row7 col4" >6.000000</td>
#       <td id="T_08745_row7_col5" class="data row7 col5" >has 213 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_08745_level0_row8" class="row_heading level0 row8" >Ticket</th>
#       <td id="T_08745_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_08745_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_08745_row8_col2" class="data row8 col2" >76</td>
#       <td id="T_08745_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_08745_row8_col4" class="data row8 col
# Number of All Scatter Plots = 3
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Administrador\AppData\Roaming\nltk_data.
# [nltk_data]    |     ..
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# All Plots done
# Time to run AutoViz = 28 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# From this, we can conclude:
#
# * We could eliminate "Name" and "Ticket" features since they have unique values and do not give important information about whether a passenger survived or not
#
# * "Age", "Sibsp", "Parch" and "Fare" seem to have outlier values. We could analyze them by using boxplots.
#
# * Some features seem to be imbalanced (There are a lot more rows of one type than the others): Survived, Pclass, Sex, SibSP, Parch and Embarked
#
# * It may be useful to create distplots for Age and Fare
#
# * There seems to be a strong correlation between Fare and Pclass
