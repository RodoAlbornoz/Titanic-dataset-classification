# %% [markdown]
# Let's now apply all the things that we got from the EDA and Auto EDA libraries analysis

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Print library versions to avoid conflicts

# %%
print(f'Pandas Version: {pd.__version__}') 
print(f'Numpy Version: {np.__version__}') 
print(f'Matplotlib version: {matplotlib.__version__}')
print(f'Seaborn version: {sns.__version__}')
# Out:
# Pandas Version: 1.5.3
# Numpy Version: 1.23.5
# Matplotlib version: 3.6.3
# Seaborn version: 0.12.2

# %% [markdown]
# Add some configurations

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 3)
pd.set_option('plotting.backend', 'matplotlib') 
pd.options.mode.chained_assignment = None
np.set_printoptions(suppress=True)
pd.options.display.float_format = '{:.4f}'.format

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,7)

# %% [markdown]
# Load train and test datasets

# %%
ds_titanic_train = pd.read_csv(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\train.csv", encoding = 'unicode_escape')
ds_work = ds_titanic_train.copy()

ds_titanic_test = pd.read_csv(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\test.csv", encoding = 'unicode_escape')
ds_test = ds_titanic_test.copy()

# %% [markdown]
# # Check correct load of data set

# %% [markdown]
# Show first 10 registers

# %%
ds_work.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.0000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.0000      1
# 2                               Heikkinen, Miss. Laina  female 26.0000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.0000      1
# 4                             Allen, Mr. William Henry    male 35.0000      0
# 5                                     Moran, Mr. James    male     NaN      0
# 6                              McCarthy, Mr. Timothy J    male 54.0000      0
# 7                       Palsson, Master. Gosta Leonard    male  2.0000      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female 27.0000      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female 14.0000      1
#
#    Parch            Ticket    Fare Cabin Embarked
# 0      0         A/5 21171  7.2500   NaN        S
# 1      0          PC 17599 71.2833   C85        C
# 2      0  STON/O2. 3101282  7.9250   NaN        S
# 3      0            113803 53.1000  C123        S
# 4      0            373450  8.0500   NaN        S
# 5      0            330877  8.4583   NaN        Q
# 6      0             17463 51.8625   E46        S
# 7      1            349909 21.0750   NaN        S
# 8      2            347742 11.1333   NaN        S
# 9      0            237736 30.0708   NaN        C

# %%
ds_test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#       Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 0 34.5000      0      0     330911  7.8292   NaN        Q
# 1 47.0000      1      0     363272  7.0000   NaN        S
# 2 62.0000      0      0     240276  9.6875   NaN        Q
# 3 27.0000      0      0     315154  8.6625   NaN        S
# 4 22.0000      1      1    3101298 12.2875   NaN        S
# 5 14.0000      0      0       7538  9.2250   NaN        S
# 6 30.0000      0      0     330972  7.6292   NaN        Q
# 7 26.0000      1      1     248738 29.0000   NaN        S
# 8 18.0000      0      0       2657  7.2292   NaN        C
# 9 21.0000      2      0  A/4 48871 24.1500   NaN        S

# %% [markdown]
# Show last 10 registers

# %%
ds_work.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex     Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 881    male 33.0000      0      0            349257  7.8958   NaN        S
# 882  female 22.0000      0      0              7552 10.5167   NaN        S
# 883    male 28.0000      0      0  C.A./SOTON 34068 10.5000   NaN        S
# 884    male 25.0000      0      0   SOTON/OQ 392076  7.0500   NaN        S
# 885  female 39.0000      0      5            382652 29.1250   NaN        Q
# 886    male 27.0000      0      0            211536 13.0000   NaN        S
# 887  female 19.0000      0      0            112053 30.0000   B42        S
# 888  female     NaN      1      2        W./C. 6607 23.4500   NaN        S
# 889    male 26.0000      0      0            111369 30.0000  C148        C
# 890    male 32.0000      0      0            370376  7.7500   NaN        Q

# %%
ds_test.tail(10)
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex     Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 408  female     NaN      0      0              334915   7.7208   NaN        Q
# 409  female  3.0000      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 410  female     NaN      0      0              365237   7.7500   NaN        Q
# 411  female 37.0000      1      0               19928  90.0000   C78        Q
# 412  female 28.0000      0      0              347086   7.7750   NaN        S
# 413    male     NaN      0      0           A.5. 3236   8.0500   NaN        S
# 414  female 39.0000      0      0            PC 17758 108.9000  C105        C
# 415    male 38.5000      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416    male     NaN      0      0              359309   8.0500   NaN        S
# 417    male     NaN      1      1                2668  22.3583   NaN        C

# %% [markdown]
# Show 10 random registers

# %%
ds_work.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 711          712         0       1                       Klaber, Mr. Herman
# 503          504         0       3           Laitinen, Miss. Kristina Sofia
# 495          496         0       3                    Yousseff, Mr. Gerious
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 174          175         0       1                  Smith, Mr. James Clinch
# 59            60         0       3       Goodwin, Master. William Frederick
# 641          642         1       1                     Sagesser, Mlle. Emma
# 479          480         1       3                 Hirvonen, Miss. Hildur E
# 766          767         0       1                Brewe, Dr. Arthur Jackson
# 39            40         1       3              Nicola-Yarred, Miss. Jamila
#
#         Sex     Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 711    male     NaN      0      0      113028 26.5500  C124        S
# 503  female 37.0000      0      0        4135  9.5875   NaN        S
# 495    male     NaN      0      0        2627 14.4583   NaN        C
# 472  female 33.0000      1      2  C.A. 34651 27.7500   NaN        S
# 174    male 56.0000      0      0       17764 30.6958    A7        C
# 59     male 11.0000      5      2     CA 2144 46.9000   NaN        S
# 641  female 24.0000      0      0    PC 17477 69.3000   B35        C
# 479  female  2.0000      0      1     3101298 12.2875   NaN        S
# 766    male     NaN      0      0      112379 39.6000   NaN        C
# 39   female 14.0000      1      0        2651 11.2417   NaN        C

# %%
ds_test.sample(10)
# Out:
#      PassengerId  Pclass  \
# 47           939       3
# 80           972       3
# 391         1283       1
# 330         1222       2
# 219         1111       3
# 415         1307       3
# 206         1098       3
# 207         1099       2
# 160         1052       3
# 89           981       2
#
#                                                        Name     Sex     Age  \
# 47                                 Shaughnessy, Mr. Patrick    male     NaN
# 80                                     Boulos, Master. Akar    male  6.0000
# 391          Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female 51.0000
# 330  Davies, Mrs. John Morgan (Elizabeth Agnes Mary White)   female 48.0000
# 219                         Thomson, Mr. Alexander Morrison    male     NaN
# 415                            Saether, Mr. Simon Sivertsen    male 38.5000
# 206                                McGowan, Miss. Katherine  female 35.0000
# 207                            Collett, Mr. Sidney C Stuart    male 24.0000
# 160                                      Smyth, Miss. Julia  female     NaN
# 89                              Wells, Master. Ralph Lester    male  2.0000
#
#      SibSp  Parch              Ticket    Fare Cabin Embarked
# 47       0      0              370374  7.7500   NaN        Q
# 80       1      1                2678 15.2458   NaN        C
# 391      0      1            PC 17592 39.4000   D28        S
# 330      0      2          C.A. 33112 36.7500   NaN        S
# 219      0      0               32302  8.0500   NaN        S
# 415      0      0  SOTON/O.Q. 3101262  7.2500   NaN        S
# 206      0      0                9232  7.7500   NaN        Q
# 207      0      0               28034 10.5000   NaN        S
# 160      0      0              335432  7.7333   NaN        Q
# 89       1      1               29103 23.0000   NaN        S

# %% [markdown]
# Shapes of the datasets

# %%
ds_work.shape
# Out:
# (891, 12)

# %%
ds_test.shape
# Out:
# (418, 11)

# %% [markdown]
# # Outlier Analysis

# %% [markdown]
# We found in our analysis that there might be outliers for 4 features: Age, SibSp, Parch and Fare. We are going to check them individually, but later, we will check them on a different jupyter notebook using specific libraries.

# %% [markdown]
# ## Outliers for Age

# %% [markdown]
# From the histogram before, we supposed that ages around 70 could be outliers. Our analysis also told us that ages greater than 64.81 may be considered outliers. Let's check those values

# %%
ds_work[ds_work["Age"] > 64.81].sort_values(by = "Age")
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 33            34         0       2                 Wheadon, Mr. Edward H
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 116          117         0       3                  Connors, Mr. Patrick
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex     Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 54   male 65.0000      0      1      113509 61.9792   B30        C
# 280  male 65.0000      0      0      336439  7.7500   NaN        Q
# 456  male 65.0000      0      0       13509 26.5500   E38        S
# 33   male 66.0000      0      0  C.A. 24579 10.5000   NaN        S
# 672  male 70.0000      0      0  C.A. 24580 10.5000   NaN        S
# 745  male 70.0000      1      1   WE/P 5735 71.0000   B22        S
# 116  male 70.5000      0      0      370369  7.7500   NaN        Q
# 96   male 71.0000      0      0    PC 17754 34.6542    A5        C
# 493  male 71.0000      0      0    PC 17609 49.5042   NaN        C
# 851  male 74.0000      0      0      347060  7.7750   NaN        S
# 630  male 80.0000      0      0       27042 30.0000   A23        S

# %% [markdown]
# The only relevant info we can get is that almost all of them died, and they were all males. There doesn't seem anything wrong with these values.

# %% [markdown]
# Let's check a boxplot for Age for better understanding.

# %%
sns.boxplot(data = ds_work, x = "Age")
# Out:
# <AxesSubplot: xlabel='Age'>

# %% [markdown]
# Let's calculate the 0.25-percentile (q1) and the 0.75-percentile (q3) to calculate the interquartile range (iqr) and check where the most common values for Age are

# %%
q1_age = np.percentile(ds_work["Age"], [25])
q1_age[0]
# Out:
# nan

# %%
q3_age = np.percentile(ds_work["Age"], [75])
q3_age[0]
# Out:
# nan

# %%
iqr_age = q3_age - q1_age
iqr_age[0]
# Out:
# nan

# %% [markdown]
# Even if most common values for Age are between 6 and 35 years, there is nothing wrong with those values above 64.81. Logically, ages greater than 64.81 are possible (Even 80 years).
# In conclussion, it is not neccesary to delete them.

# %% [markdown]
# ## Outliers for SibSp

# %% [markdown]
# Let's first check a histogram for SibSp

# %%
sns.histplot(data = ds_work, x = "SibSp", bins = 30)
# Out:
# <AxesSubplot: xlabel='SibSp', ylabel='Count'>

# %% [markdown]
# It seems like values greater than or equal to 2 seem less common. Our analysis also told us that Sibsp values greater than 2.50 may be considered outliers. Let's check those values

# %%
ds_work[ds_work["SibSp"] > 2.50].sort_values(by = "SibSp")
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 374          375         0       3
# 24            25         0       3
# 27            28         0       1
# 819          820         0       3
# 229          230         0       3
# 63            64         0       3
# 409          410         0       3
# 726          727         1       2
# 85            86         1       3
# 88            89         1       1
# 341          342         1       1
# 642          643         0       3
# 634          635         0       3
# 485          486         0       3
# 176          177         0       3
# 686          687         0       3
# 542          543         0       3
# 787          788         0       3
# 813          814         0       3
# 824          825         0       3
# 541          542         0       3
# 278          279         0       3
# 266          267         0       3
# 171          172         0       3
# 261          262         1       3
# 233          234         1       3
# 68            69         1       3
# 119          120         0       3
# 182          183         0       3
# 16            17         0       3
# 50            51         0       3
# 164          165         0       3
# 850          851         0       3
# 71            72         0       3
# 59            60         0       3
# 480          481         0       3
# 386          387         0       3
# 683          684         0       3
# 846          847         0       3
# 324          325         0       3
# 159          160         0       3
# 180          181         0       3
# 201          202         0       3
# 792          793         0       3
# 863          864         0       3
#
#                                                         Name     Sex     Age  \
# 7                             Palsson, Master. Gosta Leonard    male  2.0000
# 374                               Palsson, Miss. Stina Viola  female  3.0000
# 24                             Palsson, Miss. Torborg Danira  female  8.0000
# 27                            Fortune, Mr. Charles Alexander    male 19.0000
# 819                             Skoog, Master. Karl Thorsten    male 10.0000
# 229                                  Lefebre, Miss. Mathilde  female     NaN
# 63                                     Skoog, Master. Harald    male  4.0000
# 409                                       Lefebre, Miss. Ida  female     NaN
# 726              Renouf, Mrs. Peter Henry (Lillian Jefferys)  female 30.0000
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)  female 33.0000
# 88                                Fortune, Miss. Mabel Helen  female 23.0000
# 341                           Fortune, Miss. Alice Elizabeth  female 24.0000
# 642                            Skoog, Miss. Margit Elizabeth  female  2.0000
# 634                                       Skoog, Miss. Mabel  female  9.0000
# 485                                   Lefebre, Miss. Jeannie  female     NaN
# 176                            Lefebre, Master. Henry Forbes    male     NaN
# 686                                 Panula, Mr. Jaako Arnold    male 14.0000
# 542                        Andersson, Miss. Sigrid Elisabeth  female 11.0000
# 787                                Rice, Master. George Hugh    male  8.0000
# 813                       Andersson, Miss. Ebba Iris Alfrida  female  6.0000
# 824                             Panula, Master. Urho Abraham    male  2.0000
# 541                     Andersson, Miss. Ingeborg Constanzia  female  9.0000
# 278                                       Rice, Master. Eric    male  7.0000
# 266                                Panula, Mr. Ernesti Arvid    male 16.0000
# 171                                     Rice, Master. Arthur    male  4.0000
# 261                        Asplund, Master. Edvin Rojj Felix    male  3.0000
# 233                           Asplund, Miss. Lillian Gertrud  female  5.0000
# 68                           Andersson, Miss. Erna Alexandra  female 17.0000
# 119                        Andersson, Miss. Ellis Anna Maria  female  2.0000
# 182                    Asplund, Master. Clarence Gustaf Hugo    male  9.0000
# 16                                      Rice, Master. Eugene    male  2.0000
# 50                                Panula, Master. Juha Niilo    male  7.0000
# 164                             Panula, Master. Eino Viljami    male  1.0000
# 850                  Andersson, Master. Sigvard Harald Elias    male  4.0000
# 71                                Goodwin, Miss. Lillian Amy  female 16.0000
# 59                        Goodwin, Master. William Frederick    male 11.0000
# 480                           Goodwin, Master. Harold Victor    male  9.0000
# 386                          Goodwin, Master. Sidney Leonard    male  1.0000
# 683                              Goodwin, Mr. Charles Edward    male 14.0000
# 846                                 Sage, Mr. Douglas Bullen    male     NaN
# 324                                 Sage, Mr. George John Jr    male     NaN
# 159                               Sage, Master. Thomas Henry    male     NaN
# 180                             Sage, Miss. Constance Gladys  female     NaN
# 201                                      Sage, Mr. Frederick    male     NaN
# 792                                  Sage, Miss. Stella Anna  female     NaN
# 863                        Sage, Miss. Dorothy Edith "Dolly"  female     NaN
#
#      SibSp  Parch    Ticket     Fare        Cabin Embarked
# 7        3      1    349909  21.0750          NaN        S
# 374      3      1    349909  21.0750          NaN        S
# 24       3      1    349909  21.0750          NaN        S
# 27       3      2     19950 263.0000  C23 C25 C27        S
# 819      3      2    347088  27.9000          NaN        S
# 229      3      1      4133  25.4667          NaN        S
# 63       3      2    347088  27.9000          NaN        S
# 409      3      1      4133  25.4667          NaN        S
# 726      3      0     31027  21.0000          NaN        S
# 85       3      0   3101278  15.8500          NaN        S
# 88       3      2     19950 263.0000  C23 C25 C27        S
# 341      3      2     19950 263.0000  C23 C25 C27        S
# 642      3      2    347088  27.9000          NaN        S
# 634      3      2    347088  27.9000          NaN        S
# 485      3      1      4133  25.4667          NaN        S
# 176      3      1      4133  25.4667          NaN        S
# 686      4      1   3101295  39.6875          NaN        S
# 542      4      2    347082  31.2750          NaN        S
# 787      4      1    382652  29.1250          NaN        Q
# 813      4      2    347082  31.2750          NaN        S
# 824      4      1   3101295  39.6875          NaN        S
# 541      4      2    347082  31.2750          NaN        S
# 278      4      1    382652  29.1250          NaN        Q
# 266      4      1   3101295  39.6875          NaN        S
# 171      4      1    382652  29.1250          NaN        Q
# 261      4      2    347077  31.3875          NaN        S
# 233      4      2    347077  31.3875          NaN        S
# 68       4      2   3101281   7.9250          NaN        S
# 119      4      2    347082  31.2750          NaN        S
# 182      4      2    347077  31.3875          NaN        S
# 16       4      1    382652  29.1250          NaN        Q
# 50       4      1   3101295  39.6875          NaN        S
# 164      4      1   3101295  39.6875          NaN        S
# 850      4      2    347082  31.2750          NaN        S
# 71       5      2   CA 2144  46.9000          NaN        S
# 59       5      2   CA 2144  46.9000          NaN        S
# 480      5      2   CA 2144  46.9000          NaN        S
# 386      5      2   CA 2144  46.9000          NaN        S
# 683      5      2   CA 2144  46.9000          NaN        S
# 846      8      2  CA. 2343  69.5500          NaN        S
# 324      8      2  CA. 2343  69.5500          NaN        S
# 159      8      2  CA. 2343  69.5500          NaN        S
# 180      8      2  CA. 2343  69.5500          NaN        S
# 201      8      2  CA. 2343  69.5500          NaN        S
# 792      8      2  CA. 2343  69.5500          NaN        S
# 863      8      2  CA. 2343  69.5500          NaN        S

# %% [markdown]
# Those rows with equal SibSp values, given the passengers have same last name and given they have the same values for Embarked, Fare, Parch, Ticket and Cabin, seem to represent siblings, as the feature "SibSp" gives information about siblings aboard.

# %% [markdown]
# Let's check a boxplot for SibSp for better understanding.

# %%
sns.boxplot(data = ds_work, x = "SibSp")
# Out:
# <AxesSubplot: xlabel='SibSp'>

# %% [markdown]
# Since SibSp takes only few values, we can easily conclude that the 0.25-percentile (q1) is 0, the 0.75-percentile (q3) is 1, and the IQR is 1. So, even if an amount of 0 or 1 siblings/spouses were more common, it is logical and it makes sense to have siblings greater than 2 (Even 8 siblings/spouses). In conclussion, it is not neccesary to delete them.

# %% [markdown]
# ## Outliers for Parch

# %% [markdown]
# Let's first check a histogram for SibSp

# %%
sns.histplot(data = ds_work, x = "Parch", bins = 30)
# Out:
# <AxesSubplot: xlabel='Parch', ylabel='Count'>

# %% [markdown]
# Even if our analysis also told us that Parch values greater than 0 may be considered outliers, values greater than or equal to 3 seem less common. Let's check those values

# %%
ds_work[ds_work["Parch"] >= 3].sort_values(by = "Parch")
# Out:
#      PassengerId  Survived  Pclass  \
# 86            87         0       3
# 437          438         1       2
# 736          737         0       3
# 774          775         1       2
# 858          859         1       3
# 167          168         0       3
# 360          361         0       3
# 438          439         0       1
# 567          568         0       3
# 13            14         0       3
# 25            26         1       3
# 610          611         0       3
# 638          639         0       3
# 885          886         0       3
# 678          679         0       3
#
#                                                           Name     Sex  \
# 86                                      Ford, Mr. William Neal    male
# 437                      Richards, Mrs. Sidney (Emily Hocking)  female
# 736                    Ford, Mrs. Edward (Margaret Ann Watson)  female
# 774                      Hocking, Mrs. Elizabeth (Eliza Needs)  female
# 858                      Baclini, Mrs. Solomon (Latifa Qurban)  female
# 167            Skoog, Mrs. William (Anna Bernhardina Karlsson)  female
# 360                                         Skoog, Mr. Wilhelm    male
# 438                                          Fortune, Mr. Mark    male
# 567                Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 13                                 Andersson, Mr. Anders Johan    male
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)  female
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstantia Brogren)  female
# 638                     Panula, Mrs. Juha (Maria Emilia Ojala)  female
# 885                       Rice, Mrs. William (Margaret Norton)  female
# 678                    Goodwin, Mrs. Frederick (Augusta Tyler)  female
#
#         Age  SibSp  Parch      Ticket     Fare        Cabin Embarked
# 86  16.0000      1      3  W./C. 6608  34.3750          NaN        S
# 437 24.0000      2      3       29106  18.7500          NaN        S
# 736 48.0000      1      3  W./C. 6608  34.3750          NaN        S
# 774 54.0000      1      3       29105  23.0000          NaN        S
# 858 24.0000      0      3        2666  19.2583          NaN        C
# 167 45.0000      1      4      347088  27.9000          NaN        S
# 360 40.0000      1      4      347088  27.9000          NaN        S
# 438 64.0000      1      4       19950 263.0000  C23 C25 C27        S
# 567 29.0000      0      4      349909  21.0750          NaN        S
# 13  39.0000      1      5      347082  31.2750          NaN        S
# 25  38.0000      1      5      347077  31.3875          NaN        S
# 610 39.0000      1      5      347082  31.2750          NaN        S
# 638 41.0000      0      5     3101295  39.6875          NaN        S
# 885 39.0000      0      5      382652  29.1250          NaN        Q
# 678 43.0000      1      6     CA 2144  46.9000          NaN        S

# %% [markdown]
# This doesn't give any important relationship.

# %% [markdown]
# Let's check a boxplot for Parch for better understanding.

# %%
sns.boxplot(data = ds_work, x = "Parch")
# Out:
# <AxesSubplot: xlabel='Parch'>

# %% [markdown]
# This also doesn't give us valuable information. Even if Parch values greater than 0 are less common, just like with SibSp, it is possible to have more than 0 parents/children.
# In conclussion, it is not neccesary to delete these values.

# %% [markdown]
# ## Outliers for Fare

# %% [markdown]
# From the histogram before, we supposed that some values may be outliers. Our analysis also told us that Fare values greater than 65.63 may be considered outliers. Let's check those values

# %%
ds_work[ds_work["Fare"] >= 65.63].sort_values(by = "Fare")
# Out:
#      PassengerId  Survived  Pclass  \
# 336          337         0       1
# 151          152         1       1
# 369          370         1       1
# 641          642         1       1
# 846          847         0       3
# 324          325         0       3
# 863          864         0       3
# 792          793         0       3
# 201          202         0       3
# 180          181         0       3
# 159          160         0       3
# 540          541         1       1
# 745          746         0       1
# 1              2         1       1
# 120          121         0       2
# 385          386         0       2
# 72            73         0       2
# 655          656         0       2
# 665          666         0       2
# 366          367         1       1
# 218          219         1       1
# 681          682         1       1
# 52            53         1       1
# 645          646         1       1
# 124          125         0       1
# 102          103         0       1
# 627          628         1       1
# 765          766         1       1
# 275          276         1       1
# 496          497         1       1
# 591          592         1       1
# 741          742         0       1
# 290          291         1       1
# 139          140         0       1
# 587          588         1       1
# 256          257         1       1
# 789          790         0       1
# 585          586         1       1
# 262          263         0       1
# 558          559         1       1
# 61            62         1       1
# 829          830         1       1
# 445          446         1       1
# 375          376         1       1
# 34            35         0       1
# 835          836         1       1
# 879          880         1       1
# 310          311         1       1
# 62            63         0       1
# 230          231         1       1
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
# 849          850         1       1
# 453          454         1       1
# 245          246         0       1
# 486          487         1       1
# 224          225         1       1
# 412          413         1       1
# 484          485         1       1
# 291          292         1       1
# 820          821         1       1
# 520          521         1       1
# 544          545         0       1
# 537          538         1       1
# 307          308         1       1
# 505          506         0       1
# 698          699         0       1
# 581          582         1       1
# 550          551         1       1
# 306          307         1       1
# 659          660         0       1
# 393          394         1       1
# 215          216         1       1
# 802          803         1       1
# 763          764         1       1
# 390          391         1       1
# 435          436         1       1
# 334          335         1       1
# 660          661         1       1
# 337          338         1       1
# 319          320         1       1
# 269          270         1       1
# 325          326         1       1
# 373          374         0       1
# 31            32         1       1
# 195          196         1       1
# 305          306         1       1
# 498          499         0       1
# 297          298         0       1
# 708          709         1       1
# 609          610         1       1
# 268          269         1       1
# 332          333         0       1
# 856          857         1       1
# 318          319         1       1
# 730          731         1       1
# 689          690         1       1
# 779          780         1       1
# 377          378         0       1
# 527          528         0       1
# 557          558         0       1
# 700          701         1       1
# 380          381         1       1
# 716          717         1       1
# 118          119         0       1
# 299          300         1       1
# 742          743         1       1
# 311          312         1       1
# 88            89         1       1
# 438          439         0       1
# 27            28         0       1
# 341          342         1       1
# 679          680         1       1
# 737          738         1       1
# 258          259         1       1
#
#                                                                                    Name  \
# 336                                                           Pears, Mr. Thomas Clinton
# 151                                                   Pears, Mrs. Thomas (Edith Wearne)
# 369                                                       Aubart, Mme. Leontine Pauline
# 641                                                                Sagesser, Mlle. Emma
# 846                                                            Sage, Mr. Douglas Bullen
# 324                                                            Sage, Mr. George John Jr
# 863                                                   Sage, Miss. Dorothy Edith "Dolly"
# 792                                                             Sage, Miss. Stella Anna
# 201                                                                 Sage, Mr. Frederick
# 180                                                        Sage, Miss. Constance Gladys
# 159                                                          Sage, Master. Thomas Henry
# 540                                                             Crosby, Miss. Harriet R
# 745                                                        Crosby, Capt. Edward Gifford
# 1                                   Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 120                                                         Hickman, Mr. Stanley George
# 385                                                           Davies, Mr. Charles Henry
# 72                                                                 Hood, Mr. Ambrose Jr
# 655                                                           Hickman, Mr. Leonard Mark
# 665                                                                  Hickman, Mr. Lewis
# 366                                    Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 218                                                               Bazzani, Miss. Albina
# 681                                                                  Hassab, Mr. Hammad
# 52                                             Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 645                                                           Harper, Mr. Henry Sleeper
# 124                                                         White, Mr. Percival Wayland
# 102                                                           White, Mr. Richard Frasar
# 627                                                       Longley, Miss. Gretchen Fiske
# 765                                                Hogeboom, Mrs. John C (Anna Andrews)
# 275                                                   Andrews, Miss. Kornelia Theodosia
# 496                                                      Eustis, Miss. Elizabeth Mussey
# 591                                     Stephenson, Mrs. Walter Bertram (Martha Eustis)
# 741                                                       Cavendish, Mr. Tyrell William
# 290                                                        Barber, Miss. Ellen "Nellie"
# 139                                                                  Giglio, Mr. Victor
# 587                                                    Frolicher-Stehli, Mr. Maxmillian
# 256                                                      Thorne, Mrs. Gertrude Maybelle
# 789                                                            Guggenheim, Mr. Benjamin
# 585                                                                 Taussig, Miss. Ruth
# 262                                                                   Taussig, Mr. Emil
# 558                                              Taussig, Mrs. Emil (Tillie Mandelbaum)
# 61                                                                  Icard, Miss. Amelie
# 829                                           Stone, Mrs. George Nelson (Martha Evelyn)
# 445                                                           Dodge, Master. Washington
# 375                                               Meyer, Mrs. Edgar Joseph (Leila Saks)
# 34                                                              Meyer, Mr. Edgar Joseph
# 835                                                         Compton, Miss. Sara Rebecca
# 879                                       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 310                                                      Hays, Miss. Margaret Bechstein
# 62                                                          Harris, Mr. Henry Birkhardt
# 230                                        Harris, Mrs. Henry Birkhardt (Irene Wallach)
# 257                                                                Cherry, Miss. Gladys
# 504                                                               Maioni, Miss. Roberta
# 759                            Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)
# 849                                        Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 453                                                            Goldenberg, Mr. Samuel L
# 245                                                         Minahan, Dr. William Edward
# 486                                     Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)
# 224                                                        Hoyt, Mr. Frederick Maxfield
# 412                                                              Minahan, Miss. Daisy E
# 484                                                             Bishop, Mr. Dickinson H
# 291                                             Bishop, Mrs. Dickinson H (Helen Walton)
# 820                                  Hays, Mrs. Charles Melville (Clara Jennings Gregg)
# 520                                                               Perreault, Miss. Anne
# 544                                                          Douglas, Mr. Walter Donald
# 537                                                                 LeRoy, Miss. Bertha
# 307  Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)
# 505                                          Penasco y Castellana, Mr. Victor de Satode
# 698                                                            Thayer, Mr. John Borland
# 581                                Thayer, Mrs. John Borland (Marian Longstreth Morris)
# 550                                                         Thayer, Mr. John Borland Jr
# 306                                                             Fleming, Miss. Margaret
# 659                                                          Newell, Mr. Arthur Webster
# 393                                                              Newell, Miss. Marjorie
# 215                                                             Newell, Miss. Madeleine
# 802                                                 Carter, Master. William Thornton II
# 763                                           Carter, Mrs. William Ernest (Lucile Polk)
# 390                                                          Carter, Mr. William Ernest
# 435                                                           Carter, Miss. Lucile Polk
# 334                                  Frauenthal, Mrs. Henry William (Clara Heinsheimer)
# 660                                                       Frauenthal, Dr. Henry William
# 337                                                     Burns, Miss. Elizabeth Margaret
# 319                            Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)
# 269                                                              Bissette, Miss. Amelia
# 325                                                            Young, Miss. Marie Grice
# 373                                                                 Ringhini, Mr. Sante
# 31                                       Spencer, Mrs. William Augustus (Marie Eugenie)
# 195                                                                Lurette, Miss. Elise
# 305                                                      Allison, Master. Hudson Trevor
# 498                                     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 297                                                        Allison, Miss. Helen Loraine
# 708                                                                Cleaver, Miss. Alice
# 609                                                           Shutes, Miss. Elizabeth W
# 268                                       Graham, Mrs. William Thompson (Edith Junkins)
# 332                                                           Graham, Mr. George Edward
# 856                                          Wick, Mrs. George Dennick (Mary Hitchcock)
# 318                                                            Wick, Miss. Mary Natalie
# 730                                                       Allen, Miss. Elisabeth Walton
# 689                                                   Madill, Miss. Georgette Alexandra
# 779                               Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)
# 377                                                           Widener, Mr. Harry Elkins
# 527                                                                  Farthing, Mr. John
# 557                                                                 Robbins, Mr. Victor
# 700                                   Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 380                                                               Bidois, Miss. Rosalie
# 716                                                       Endres, Miss. Caroline Louise
# 118                                                            Baxter, Mr. Quigg Edmond
# 299                                     Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 742                                               Ryerson, Miss. Susan Parker "Suzette"
# 311                                                          Ryerson, Miss. Emily Borie
# 88                                                           Fortune, Miss. Mabel Helen
# 438                                                                   Fortune, Mr. Mark
# 27                                                       Fortune, Mr. Charles Alexander
# 341                                                      Fortune, Miss. Alice Elizabeth
# 679                                                  Cardeza, Mr. Thomas Drake Martinez
# 737                                                              Lesurer, Mr. Gustave J
# 258                                                                    Ward, Miss. Anna
#
#         Sex     Age  SibSp  Parch        Ticket     Fare            Cabin  \
# 336    male 29.0000      1      0        113776  66.6000               C2
# 151  female 22.0000      1      0        113776  66.6000               C2
# 369  female 24.0000      0      0      PC 17477  69.3000              B35
# 641  female 24.0000      0      0      PC 17477  69.3000              B35
# 846    male     NaN      8      2      CA. 2343  69.5500              NaN
# 324    male     NaN      8      2      CA. 2343  69.5500              NaN
# 863  female     NaN      8      2      CA. 2343  69.5500              NaN
# 792  female     NaN      8      2      CA. 2343  69.5500              NaN
# 201    male     NaN      8      2      CA. 2343  69.5500              NaN
# 180  female     NaN      8      2      CA. 2343  69.5500              NaN
# 159    male     NaN      8      2      CA. 2343  69.5500              NaN
# 540  female 36.0000      0      2     WE/P 5735  71.0000              B22
# 745    male 70.0000      1      1     WE/P 5735  71.0000              B22
# 1    female 38.0000      1      0      PC 17599  71.2833              C85
# 120    male 21.0000      2      0  S.O.C. 14879  73.5000              NaN
# 385    male 18.0000      0      0  S.O.C. 14879  73.5000              NaN
# 72     male 21.0000      0      0  S.O.C. 14879  73.5000              NaN
# 655    male 24.0000      2      0  S.O.C. 14879  73.5000              NaN
# 665    male 32.0000      2      0  S.O.C. 14879  73.5000              NaN
# 366  female 60.0000      1      0        110813  75.2500              D37
# 218  female 32.0000      0      0         11813  76.2917              D15
# 681    male 27.0000      0      0      PC 17572  76.7292              D49
# 52   female 49.0000      1      0      PC 17572  76.7292              D33
# 645    male 48.0000      1      0      PC 17572  76.7292              D33
# 124    male 54.0000      0      1         35281  77.2875              D26
# 102    male 21.0000      0      1         35281  77.2875              D26
# 627  female 21.0000      0      0         13502  77.9583               D9
# 765  female 51.0000      1      0         13502  77.9583              D11
# 275  female 63.0000      1      0         13502  77.9583               D7
# 496  female 54.0000      1      0         36947  78.2667              D20
# 591  female 52.0000      1      0         36947  78.2667              D20
# 741    male 36.0000      1      0         19877  78.8500              C46
# 290  female 26.0000      0      0         19877  78.8500              NaN
# 139    male 24.0000      0      0      PC 17593  79.2000              B86
# 587    male 60.0000      1      1         13567  79.2000              B41
# 256  female     NaN      0      0      PC 17585  79.2000              NaN
# 789    male 46.0000      0      0      PC 17593  79.2000          B82 B84
# 585  female 18.0000      0      2        110413  79.6500              E68
# 262    male 52.0000      1      1        110413  79.6500              E67
# 558  female 39.0000      1      1        110413  79.6500              E67
# 61   female 38.0000      0      0        113572  80.0000              B28
# 829  female 62.0000      0      0        113572  80.0000              B28
# 445    male  4.0000      0      2         33638  81.8583              A34
# 375  female     NaN      1      0      PC 17604  82.1708              NaN
# 34     male 28.0000      1      0      PC 17604  82.1708              NaN
# 835  female 39.0000      1      1      PC 17756  83.1583              E49
# 879  female 56.0000      0      1         11767  83.1583              C50
# 310  female 24.0000      0      0         11767  83.1583              C54
# 62     male 45.0000      1      0         36973  83.4750              C83
# 230  female 35.0000      1      0         36973  83.4750              C83
# 257  female 30.0000      0      0        110152  86.5000              B77
# 504  female 16.0000      0      0        110152  86.5000              B79
# 759  female 33.0000      0      0        110152  86.5000              B77
# 849  female     NaN      1      0         17453  89.1042              C92
# 453    male 49.0000      1      0         17453  89.1042              C92
# 245    male 44.0000      2      0         19928  90.0000              C78
# 486  female 35.0000      1      0         19943  90.0000              C93
# 224    male 38.0000      1      0         19943  90.0000              C93
# 412  female 33.0000      1      0         19928  90.0000              C78
# 484    male 25.0000      1      0         11967  91.0792              B49
# 291  female 19.0000      1      0         11967  91.0792              B49
# 820  female 52.0000      1      1         12749  93.5000              B69
# 520  female 30.0000      0      0         12749  93.5000              B73
# 544    male 50.0000      1      0      PC 17761 106.4250              C86
# 537  female 30.0000      0      0      PC 17761 106.4250              NaN
# 307  female 17.0000      1      0      PC 17758 108.9000              C65
# 505    male 18.0000      1      0      PC 17758 108.9000              C65
# 698    male 49.0000      1      1         17421 110.8833              C68
# 581  female 39.0000      1      1         17421 110.8833              C68
# 550    male 17.0000      0      2         17421 110.8833              C70
# 306  female     NaN      0      0         17421 110.8833              NaN
# 659    male 58.0000      0      2         35273 113.2750              D48
# 393  female 23.0000      1      0         35273 113.2750              D36
# 215  female 31.0000      1      0         35273 113.2750              D36
# 802    male 11.0000      1      2        113760 120.0000          B96 B98
# 763  female 36.0000      1      2        113760 120.0000          B96 B98
# 390    male 36.0000      1      2        113760 120.0000          B96 B98
# 435  female 14.0000      1      2        113760 120.0000          B96 B98
# 334  female     NaN      1      0      PC 17611 133.6500              NaN
# 660    male 50.0000      2      0      PC 17611 133.6500              NaN
# 337  female 41.0000      0      0         16966 134.5000              E40
# 319  female 40.0000      1      1         16966 134.5000              E34
# 269  female 35.0000      0      0      PC 17760 135.6333              C99
# 325  female 36.0000      0      0      PC 17760 135.6333              C32
# 373    male 22.0000      0      0      PC 17760 135.6333              NaN
# 31   female     NaN      1      0      PC 17569 146.5208              B78
# 195  female 58.0000      0      0      PC 17569 146.5208              B80
# 305    male  0.9200      1      2        113781 151.5500          C22 C26
# 498  female 25.0000      1      2        113781 151.5500          C22 C26
# 297  female  2.0000      1      2        113781 151.5500          C22 C26
# 708  female 22.0000      0      0        113781 151.5500              NaN
# 609  female 40.0000      0      0      PC 17582 153.4625             C125
# 268  female 58.0000      0      1      PC 17582 153.4625             C125
# 332    male 38.0000      0      1      PC 17582 153.4625              C91
# 856  female 45.0000      1      1         36928 164.8667              NaN
# 318  female 31.0000      0      2         36928 164.8667               C7
# 730  female 29.0000      0      0         24160 211.3375               B5
# 689  female 15.0000      0      1         24160 211.3375               B5
# 779  female 43.0000      0      1         24160 211.3375               B3
# 377    male 27.0000      0      2        113503 211.5000              C82
# 527    male     NaN      0      0      PC 17483 221.7792              C95
# 557    male     NaN      0      0      PC 17757 227.5250              NaN
# 700  female 18.0000      1      0      PC 17757 227.5250          C62 C64
# 380  female 42.0000      0      0      PC 17757 227.5250              NaN
# 716  female 38.0000      0      0      PC 17757 227.5250              C45
# 118    male 24.0000      0      1      PC 17558 247.5208          B58 B60
# 299  female 50.0000      0      1      PC 17558 247.5208          B58 B60
# 742  female 21.0000      2      2      PC 17608 262.3750  B57 B59 B63 B66
# 311  female 18.0000      2      2      PC 17608 262.3750  B57 B59 B63 B66
# 88   female 23.0000      3      2         19950 263.0000      C23 C25 C27
# 438    male 64.0000      1      4         19950 263.0000      C23 C25 C27
# 27     male 19.0000      3      2         19950 263.0000      C23 C25 C27
# 341  female 24.0000      3      2         19950 263.0000      C23 C25 C27
# 679    male 36.0000      0      1      PC 17755 512.3292      B51 B53 B55
# 737    male 35.0000      0      0      PC 17755 512.3292             B101
# 258  female 35.0000      0      0      PC 17755 512.3292              NaN
#
#     Embarked
# 336        S
# 151        S
# 369        C
# 641        C
# 846        S
# 324        S
# 863        S
# 792        S
# 201        S
# 180        S
# 159        S
# 540        S
# 745        S
# 1          C
# 120        S
# 385        S
# 72         S
# 655        S
# 665        S
# 366        C
# 218        C
# 681        C
# 52         C
# 645        C
# 124        S
# 102        S
# 627        S
# 765        S
# 275        S
# 496        C
# 591        C
# 741        S
# 290        S
# 139        C
# 587        C
# 256        C
# 789        C
# 585        S
# 262        S
# 558        S
# 61       NaN
# 829      NaN
# 445        S
# 375        C
# 34         C
# 835        C
# 879        C
# 310        C
# 62         S
# 230        S
# 257        S
# 504        S
# 759        S
# 849        C
# 453        C
# 245        Q
# 486        S
# 224        S
# 412        Q
# 484        C
# 291        C
# 820        S
# 520        S
# 544        C
# 537        C
# 307        C
# 505        C
# 698        C
# 581        C
# 550        C
# 306        C
# 659        C
# 393        C
# 215        C
# 802        S
# 763        S
# 390        S
# 435        S
# 334        S
# 660        S
# 337        C
# 319        C
# 269        S
# 325        C
# 373        C
# 31         C
# 195        C
# 305        S
# 498        S
# 297        S
# 708        S
# 609        S
# 268        S
# 332        S
# 856        S
# 318        S
# 730        S
# 689        S
# 779        S
# 377        C
# 527        S
# 557        C
# 700        C
# 380        C
# 716        C
# 118        C
# 299        C
# 742        C
# 311        C
# 88         S
# 438        S
# 27         S
# 341        S
# 679        C
# 737        C
# 258        C

# %% [markdown]
# So, people who paid a higher Fare, usually travelled in 1st class (Which makes sense), but we can't get more important info by checking the other features.

# %% [markdown]
# Let's check a boxplot for Fare for better understanding.

# %%
sns.boxplot(data = ds_work, x = "Fare")
# Out:
# <AxesSubplot: xlabel='Fare'>

# %% [markdown]
# Let's calculate the 0.25-percentile (q1) and the 0.75-percentile (q3) to calculate the interquartile range (iqr) and check where the most common values for Fare are

# %%
q1_fare = np.percentile(ds_work["Fare"], [25])
q1_fare[0]
# Out:
# 7.9104

# %%
q3_fare = np.percentile(ds_work["Fare"], [75])
q3_fare[0]
# Out:
# 31.0

# %%
iqr_fare = q3_fare - q1_fare
iqr_fare[0]
# Out:
# 23.0896

# %% [markdown]
# Even if most common values for Fare are between 7.9104 and 31 years, there is nothing wrong with those values above 65.63. Logically, higher Fares are possible. In conclussion, it is not neccesary to delete them.

# %% [markdown]
# # Checking correlation between Fare and Pclass

# %% [markdown]
# We saw in the heatmap that Fare and Pclass are highly correlated. Let's now check their relation using a scatterplot.

# %%
plt.figure(figsize = (5, 5))
sns.scatterplot(data = ds_work, x = "Pclass" , y = "Fare")
plt.show()

# %% [markdown]
# As the heatmap said, they have a negative correlation. The higher the Pclass, the lower the Fare might be, which makes sense in real life.

# %% [markdown]
# Given their high correlation, we can delete one of them. We are going to delete the Pclass feature, since the Fare could still give us valuable information.

# %%
ds_work.drop(["Pclass"], axis = 1, inplace = True)

# %%
ds_test.drop(["Pclass"], axis = 1, inplace = True)

# %% [markdown]
# # Delete unnecesary features

# %% [markdown]
# We found that Ticket doesn't give relevant information about whether a passenger died or not. Even repeated tickets don't give any information about that. So let's delete Ticket from our datasets

# %%
ds_work.drop(["Ticket"], axis = 1, inplace = True)

# %%
ds_test.drop(["Ticket"], axis = 1, inplace = True)

# %% [markdown]
# Finally, since Cabin has 77% null values, and it doesn't give information about dead or survived passenger, we delete it

# %%
ds_work.drop(["Cabin"], axis = 1, inplace = True)

# %%
ds_test.drop(["Cabin"], axis = 1, inplace = True)

# %% [markdown]
# We check the new shapes of the datasets, they should have 2 less features

# %%
ds_work.shape
# Out:
# (891, 9)

# %%
ds_test.shape
# Out:
# (418, 8)

# %% [markdown]
# # Treating null values

# %% [markdown]
# ## Age null values

# %% [markdown]
# Before treating null values in Age, let's make a histogram for it

# %%
sns.histplot(data = ds_work, x = "Age", bins = 30)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %% [markdown]
# As an additional comment, it seems like ages around 70 could be outliers, which we are going to analyze later.

# %% [markdown]
# Let's take a better look at certain percentiles for Age

# %%
ds_work[["Age"]].describe(percentiles = [0.25, 0.30, 0.40, 0.50, 0.60, 0.7, 0.75])
# Out:
#            Age
# count 714.0000
# mean   29.6991
# std    14.5265
# min     0.4200
# 25%    20.1250
# 30%    22.0000
# 40%    25.0000
# 50%    28.0000
# 60%    31.8000
# 70%    36.0000
# 75%    38.0000
# max    80.0000

# %% [markdown]
# From the histogram and percentiles we can conclude that most people are or were between 18 and 35 years old

# %% [markdown]
# We found that Age had 177 null values (20% of the dataset). Since age seems like a more relevant feature, and we could lose valuable information by droping rows with null values for Age, we can replace those null values with zeroes.

# %%
ds_work["Age"].fillna(0, inplace = True)

# %%
ds_test["Age"].fillna(0, inplace = True)

# %% [markdown]
# Now let's check again the histogram for Age

# %%
sns.histplot(data = ds_work, x = "Age", bins = 30)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Now, the graph is skewed. We could solve this later by applying some transformation or normalization.

# %% [markdown]
# ## Embarked null values

# %% [markdown]
# We found that Embarked had 2 null values, We can check those rows with null values for Embarked

# %%
ds_work[ds_work["Embarked"].isnull()]
# Out:
#      PassengerId  Survived                                       Name     Sex  \
# 61            62         1                        Icard, Miss. Amelie  female
# 829          830         1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#         Age  SibSp  Parch    Fare Embarked
# 61  38.0000      0      0 80.0000      NaN
# 829 62.0000      0      0 80.0000      NaN

# %% [markdown]
# We could drop these rows since they don't give any valuable information

# %%
ds_work.dropna(inplace = True)

# %%
ds_test.dropna(inplace = True)

# %% [markdown]
# Now, we should have no more null values left

# %%
ds_work.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
ds_test.isnull().sum()
# Out:
# PassengerId    0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# We check the new shapes of the datasets

# %%
ds_work.shape
# Out:
# (889, 9)

# %%
ds_test.shape
# Out:
# (417, 8)

# %% [markdown]
# # Optimizing memory usage

# %% [markdown]
# Information about the features, amount of null values, data type of each feature, and others

# %%
ds_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Name         889 non-null    object
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 69.5+ KB

# %%
ds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Name         417 non-null    object
#  2   Sex          417 non-null    object
#  3   Age          417 non-null    float64
#  4   SibSp        417 non-null    int64
#  5   Parch        417 non-null    int64
#  6   Fare         417 non-null    float64
#  7   Embarked     417 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 29.3+ KB

# %% [markdown]
# Memory usage of each feature

# %%
ds_work.memory_usage()
# Out:
# Index          7112
# PassengerId    7112
# Survived       7112
# Name           7112
# Sex            7112
# Age            7112
# SibSp          7112
# Parch          7112
# Fare           7112
# Embarked       7112
# dtype: int64

# %%
ds_test.memory_usage()
# Out:
# Index          3336
# PassengerId    3336
# Name           3336
# Sex            3336
# Age            3336
# SibSp          3336
# Parch          3336
# Fare           3336
# Embarked       3336
# dtype: int64

# %% [markdown]
# Now, we change the data type of some features to save memory, but without losing info of the features.

# %% [markdown]
# These features have a small range value (PassengerId from 1 to 891; Survived only 0 and 1; SibSp from 0 to 8; Parch from 0 to 6; Fare from 0 to 512.3292; Age from 0 to 80), so we can use a smaller data type for them

# %%
ds_work["PassengerId"] = ds_work["PassengerId"].astype("int16")
ds_work["Survived"] = ds_work["Survived"].astype("int8")
ds_work["SibSp"] = ds_work["SibSp"].astype("int8")
ds_work["Parch"] = ds_work["Parch"].astype("int8")
ds_work["Fare"] = ds_work["Fare"].astype("float16")
ds_work["Age"] = ds_work["Age"].astype("float16")

# %%
ds_test["PassengerId"] = ds_test["PassengerId"].astype("int16")
ds_test["SibSp"] = ds_test["SibSp"].astype("int8")
ds_test["Parch"] = ds_test["Parch"].astype("int8")
ds_test["Fare"] = ds_test["Fare"].astype("float16")
ds_test["Age"] = ds_test["Age"].astype("float16")

# %% [markdown]
# These features only take specific values (Sex takes male and female; Embarked takes S, C, Q or nan), so we can reduce them to categorical features

# %%
ds_work["Sex"] = ds_work["Sex"].astype("category")
ds_work["Embarked"] = ds_work["Embarked"].astype("category")

# %%
ds_test["Sex"] = ds_test["Sex"].astype("category")
ds_test["Embarked"] = ds_test["Embarked"].astype("category")

# %% [markdown]
# We check again the memory usage of the entire datasets and of each feature

# %%
ds_work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int16
#  1   Survived     889 non-null    int8
#  2   Name         889 non-null    object
#  3   Sex          889 non-null    category
#  4   Age          889 non-null    float16
#  5   SibSp        889 non-null    int8
#  6   Parch        889 non-null    int8
#  7   Fare         889 non-null    float16
#  8   Embarked     889 non-null    category
# dtypes: category(2), float16(2), int16(1), int8(3), object(1)
# memory usage: 23.7+ KB

# %%
ds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int16
#  1   Name         417 non-null    object
#  2   Sex          417 non-null    category
#  3   Age          417 non-null    float16
#  4   SibSp        417 non-null    int8
#  5   Parch        417 non-null    int8
#  6   Fare         417 non-null    float16
#  7   Embarked     417 non-null    category
# dtypes: category(2), float16(2), int16(1), int8(2), object(1)
# memory usage: 10.8+ KB

# %%
ds_work.memory_usage()
# Out:
# Index          7112
# PassengerId    1778
# Survived        889
# Name           7112
# Sex            1013
# Age            1778
# SibSp           889
# Parch           889
# Fare           1778
# Embarked       1021
# dtype: int64

# %%
ds_test.memory_usage()
# Out:
# Index          3336
# PassengerId     834
# Name           3336
# Sex             541
# Age             834
# SibSp           417
# Parch           417
# Fare            834
# Embarked        549
# dtype: int64

# %% [markdown]
# Even though the datasets are small, we reduced the memory usage from 69.5 KB to 23.7 KB, and from 29.3 KB to 10.8 KB (About 2/3 of memory)

# %% [markdown]
# # Saving dataset

# %% [markdown]
# Now let's save our datasets

# %%
ds_work.to_csv(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\ds_train_processed.csv", encoding = 'latin-1', index = False, header = True, decimal = '.', sep = ',')
ds_test.to_csv(r"C:\Users\Administrador\Documents\IA\Proyectos\Titanic\Datasets\ds_test_processed.csv", encoding = 'latin-1', index = False, header = True, decimal = '.', sep = ',')
